# %% [markdown]
# ### Prerequisite for this script
# Run the first two code section and move on to batch training part.

# %%
import sys
sys.path.insert(0, "..")
basedir = "../.."

# %%
def trainer(dconfig, wconfig, nows=False, **kwargs):
    is_training = kwargs.pop("is_training", True)
    from common.config import create_object, load_config
    
    dconfig = load_config(dconfig, [f"datasize.spacedim=1"])
    dset = create_object(dconfig)
    wconfig = load_config(wconfig)
    experiment = create_object(wconfig)
    reg_name = kwargs.pop("reg_name", "base")
    
    if isinstance(experiment, models.WeldHelper):
        name = f"{dset.name}{wconfig.aeclass}{'noWS' if nows else ''}"
        k = 4# wconfig.aeparams.encodeSeq[-1] if "encodeSeq" in wconfig.aeparams else wconfig.aeparams.sample.latents_dims
        kwargs["td"] = f"{name}{reg_name}-{k}-{'auton' if  kwargs['autonomous'] else 'nonauton'}"
        weld = experiment.create_weld(dset, **kwargs)
        baseepochs = 150
        is_all_loaded = weld.load_all(name)
        if is_training:
            if not is_all_loaded and kwargs.get("windows",1) > 1:
                is_ae_prop_loaded = weld.load_aes_and_props(name,verbose=True)
            else:
                is_ae_prop_loaded = is_all_loaded

            if not is_ae_prop_loaded:
                if not weld.load_aes(name,verbose=True):
                    weld.train_aes(baseepochs, warmstart_epochs=0 if nows else baseepochs, printinterval=25, batch=16, save=True, plottb=False, lr=1e-4)
                weld.train_propagators(baseepochs * 10, batch=32, printinterval=baseepochs, save=True, lr=1e-5)
                
            if not is_all_loaded and kwargs.get("windows",1) > 1:
                weld.train_transcoders(baseepochs * 10, batch=32, printinterval=baseepochs, save=True, lr=1e-5)
        return weld
    else:
        assert(isinstance(experiment, models.TimeInputHelper))
        kwargs["td"] = f"{dset.name}{wconfig.ticlass}"
        ti = experiment.create_timeinput(dset, **kwargs)
        baseepochs = 1000
        is_all_loaded = ti.load_model(dset.name)
        if is_training:
            if not is_all_loaded:
                ti.train_model(baseepochs, printinterval=baseepochs//20, lr=1e-3)

        return ti

def batch_trainer(dconfig:str, wconfig:str, nows=False, **kwargs):
    is_training = kwargs.pop("is_training", True)
    base_config = {"reg_name":"base", "straightness":0, "kinetic":0}
    straight_config = {"reg_name":"straight", "straightness":0.1, "kinetic":0}
    kinetic_config = {"reg_name":"kinetic", "straightness":0, "kinetic":1}
    batched_welds = []
    
    regconfigs = [base_config]
    for autonomous in [True]: # autonomous = True,
        for reg_config in regconfigs:
            welds = []
            for windows in [1]:
                kwargs = {"windows": windows,
                          "autonomous": autonomous,
                          "k": 20,
                          **reg_config}
                welds.append(trainer(dconfig, wconfig, is_training=is_training, nows=nows, **kwargs))
            batched_welds.append(welds)
    return batched_welds

import models

def plots(welds:list, dir="plots"):
    import matplotlib.pyplot as plt
    import os

    if not os.path.exists(dir):
        os.makedirs(dir)

    if isinstance(welds[0], models.WeldNet):
        #print(f"We're now comparing the projection and operator errors from {welds[0].td}")
        fig = welds.WeldHelper.compare_projops(welds, windowlines=False)
        fig.tight_layout()
        fig.savefig(f"{dir}/{welds[0].td}_projopserrs.png", facecolor="white", dpi=200)
        plt.close(fig)
        
        #print(f"We're now comparing the propogation erros from {welds[0].td}")
        fig = welds.WeldHelper.compare_properrs(welds, windowlines=False)
        fig.tight_layout()
        fig.savefig(f"{dir}/{welds[0].td}_properrs.png", facecolor="white", dpi=200)
        plt.close(fig)

        fig = welds.WeldHelper.compare_errorparams(welds)
        fig.tight_layout()
        fig.savefig(f"{dir}/{welds[0].td}_errorparams.png", facecolor="white", dpi=200)
        plt.close(fig)
    else:
        #print(f"We're now comparing the projection and operator errors from {welds[0].td}")
        fig = models.TimeInputHelper.compare_operrs(welds)
        fig.savefig(f"{dir}/{welds[0].td}_operrs.png", facecolor="white", dpi=200)
        plt.close(fig)

        fig = models.TimeInputHelper.compare_errorparams(welds)
        fig.tight_layout()
        fig.savefig(f"{dir}/{welds[0].td}_errorparams.png", facecolor="white", dpi=200)
        plt.close(fig)
    
def tester(*args, **kwargs):
    weld = trainer(*args, is_training=False, **kwargs)
    plots([weld])
    
def batch_tester(*args, **kwargs):
    batched_welds = batch_trainer(*args, is_training=False, **kwargs)
    for welds in batched_welds:
        plots(welds)

# %% [markdown]
# ### WELDNET Training (& optional: Test) :
#
# *follow the following example to train our weldnet with preferable hyperparameters.*

# %% [markdown]
# ### Batched Training  (& optional: Test) ::
#
# *use "batch_trainer" with data and model configuration. Add "aeclass" keyword arguments for CNN and LSTM Autoencoder if necessary.*

# %%
DCONFIGS = {
    "bshift": "../autoencoder/configs/data/burgersshift.yaml",
    "bscale": "../autoencoder/configs/data/burgersscale.yaml",
    "tscale": "../autoencoder/configs/data/hatsscale.yaml",
    "tshift": "../autoencoder/configs/data/hatsshift.yaml",
    "kscale": "../autoencoder/configs/data/KdVscale.yaml",
    "kshift": "../autoencoder/configs/data/KdVshift.yaml",
    # "b2width": "../autoencoder/configs/data/burgers2dwidth.yaml",
    # "t2scale": "../autoencoder/configs/data/hats2dscale.yaml"
}
# DCONFIGS = {
#     "tboth": "../autoencoder/configs/data/hatsboth.yaml",
#     "tbothrandom": "../autoencoder/configs/data/hatsboth_randomt.yaml",
#     "tbothrandomstable": "../autoencoder/configs/data/hatsboth_randomtstable.yaml",
# }

# DCONFIGS = {
#     "lshift": "../autoencoder/configs/data/l96.yaml",
# }
WCONFIGS = {
    "weldff": "../autoencoder/configs/experiments/weldnormal.yaml",
    "weldpca": "../autoencoder/configs/experiments/weldpca.yaml",
    "ffti": "../autoencoder/configs/experiments/ffnetnormal.yaml",
    "donti": "../autoencoder/configs/experiments/donnormal.yaml",
}
def configure_model_and_data(dname, wname,):
    # apply your prefered modification here
    return DCONFIGS[dname], WCONFIGS[wname]
def get_all_data():
    return DCONFIGS.keys()

def get_periodic_bc_1d_data():
    return ["bshift", "bscale"]
def get_zero_bc_1d_data():
    return ["tscale", "tshift", "kscale", "kshift"]
def get_2d_data():
    return ["b2width", "t2scale"]

# %%
for dname in list(get_all_data()):
    dconfig, wconfig = configure_model_and_data(dname, "ffti")
    batch_trainer(dconfig, wconfig)
    batch_tester(dconfig, wconfig)
# Out:
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [-1.0, (500, 51, 512)]
# Load failed. Could not match with any files
# ['savedmodels/timeinput\\bshiftFFNet-01-October-2024-20.24.pickle']
# Tensorboard writer location is ./tensorboard/01-October-2024/bshiftFFNet/21.17.27/
# Number of NN trainable parameters 731712
# Starting training TI model FFNet at Tue Oct  1 21:17:27 2024...
# train torch.Size([400, 51, 512]) test (100, 51, 512)
# [0.001]
# 1: Train Loss 3.965e-02, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.355283, 0.389606, 0.724861
# [0.001]
# 51: Train Loss 6.412e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.047837, 0.053971, 0.158051
# [0.001]
# 101: Train Loss 3.716e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.040437, 0.046569, 0.136504
# [0.001]
# 151: Train Loss 4.259e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.036888, 0.041808, 0.113890
# [0.0001]
# 201: Train Loss 5.718e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.013319, 0.016507, 0.076259
# [0.0001]
# 251: Train Loss 5.216e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.012750, 0.015763, 0.071784
# [0.0001]
# 301: Train Loss 4.769e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.012264, 0.015106, 0.067471
# [0.0001]
# 351: Train Loss 4.223e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.011737, 0.014391, 0.064385
# [0.0001]
# 401: Train Loss 3.779e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.011350, 0.013797, 0.061516
# [0.0001]
# 451: Train Loss 3.607e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.010856, 0.013063, 0.057316
# [0.0001]
# 501: Train Loss 2.998e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.009923, 0.011996, 0.052778
# [0.0001]
# 551: Train Loss 2.520e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.009461, 0.011336, 0.048595
# [0.0001]
# 601: Train Loss 2.279e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.009001, 0.010744, 0.045860
# [1e-05]
# 651: Train Loss 1.737e-05, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.007686, 0.009203, 0.041432
# [1e-05]
# 701: Train Loss 1.707e-05, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.007633, 0.009134, 0.040986
# [1e-05]
# 751: Train Loss 1.674e-05, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.007581, 0.009061, 0.040670
# [1e-05]
# 801: Train Loss 1.634e-05, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.007489, 0.008944, 0.040070
# [1e-05]
# 851: Train Loss 1.590e-05, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.007402, 0.008828, 0.039257
# [1e-05]
# 901: Train Loss 1.548e-05, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.007305, 0.008700, 0.038570
# [1e-05]
# 951: Train Loss 1.501e-05, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.007198, 0.008563, 0.037950
# Finished training TI model FFNet at Tue Oct  1 21:18:49 2024...
# Model saved at savedmodels/timeinput/bshiftFFNet-01-October-2024-21.18.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [-1.0, (500, 51, 512)]
# Loading model from savedmodels/timeinput\bshiftFFNet-01-October-2024-21.18.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [4.0, (500, 51, 512)]
# Load failed. Could not match with any files
# ['savedmodels/timeinput\\bscaleFFNet-01-October-2024-20.26.pickle']
# Tensorboard writer location is ./tensorboard/01-October-2024/bscaleFFNet/21.18.59/
# Number of NN trainable parameters 731712
# Starting training TI model FFNet at Tue Oct  1 21:18:59 2024...
# train torch.Size([400, 51, 512]) test (100, 51, 512)
# [0.001]
# 1: Train Loss 1.326e-02, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.303727, 0.344060, 0.726888
# [0.001]
# 51: Train Loss 3.154e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.043813, 0.045875, 0.121862
# [0.001]
# 101: Train Loss 3.467e-05, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.018926, 0.021492, 0.077614
# [0.001]
# 151: Train Loss 1.408e-05, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.010767, 0.012849, 0.058363
# [0.0001]
# 201: Train Loss 8.820e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.008524, 0.010308, 0.049097
# [0.0001]
# 251: Train Loss 8.137e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.008206, 0.009905, 0.047175
# [0.0001]
# 301: Train Loss 7.467e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.008106, 0.009709, 0.045808
# [0.0001]
# 351: Train Loss 7.457e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.007722, 0.009208, 0.043322
# [0.0001]
# 401: Train Loss 6.751e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.007318, 0.008785, 0.042010
# [0.0001]
# 451: Train Loss 6.593e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.007607, 0.009048, 0.042102
# [0.0001]
# 501: Train Loss 6.901e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.007352, 0.008505, 0.038187
# [0.0001]
# 551: Train Loss 6.544e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.007054, 0.008068, 0.035079
# [0.0001]
# 601: Train Loss 6.016e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.006534, 0.007459, 0.032293
# [0.0001]
# 651: Train Loss 5.695e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.006265, 0.007181, 0.031293
# [0.0001]
# 701: Train Loss 5.603e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.005915, 0.006824, 0.029680
# [1e-05]
# 751: Train Loss 2.567e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.004856, 0.005595, 0.025659
# [1e-05]
# 801: Train Loss 2.461e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.004856, 0.005590, 0.025471
# [1e-05]
# 851: Train Loss 2.473e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.004881, 0.005618, 0.025406
# [1e-05]
# 901: Train Loss 2.434e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.004806, 0.005539, 0.025269
# [1e-05]
# 951: Train Loss 2.389e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.004746, 0.005474, 0.025108
# Finished training TI model FFNet at Tue Oct  1 21:20:23 2024...
# Model saved at savedmodels/timeinput/bscaleFFNet-01-October-2024-21.20.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [4.0, (500, 51, 512)]
# Loading model from savedmodels/timeinput\bscaleFFNet-01-October-2024-21.20.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [40273393.0, (500, 51, 512)]
# Load failed. Could not match with any files
# ['savedmodels/timeinput\\tscaleFFNet-01-October-2024-20.28.pickle']
# Tensorboard writer location is ./tensorboard/01-October-2024/tscaleFFNet/21.20.29/
# Number of NN trainable parameters 731712
# Starting training TI model FFNet at Tue Oct  1 21:20:29 2024...
# train torch.Size([400, 51, 512]) test (100, 51, 512)
# [0.001]
# 1: Train Loss 1.008e-02, LR 1.000e-03, Relative TI Error (1, 2, inf): 1.638294, 0.848313, 0.885102
# [0.001]
# 51: Train Loss 2.834e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.282715, 0.157229, 0.288673
# [0.001]
# 101: Train Loss 1.218e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.214788, 0.102617, 0.195396
# [0.001]
# 151: Train Loss 8.570e-05, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.155737, 0.084224, 0.167496
# [0.0001]
# 201: Train Loss 4.874e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.104871, 0.060560, 0.151993
# [0.0001]
# 251: Train Loss 4.654e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.102593, 0.059203, 0.149046
# [0.0001]
# 301: Train Loss 4.399e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.099745, 0.057570, 0.145201
# [0.0001]
# 351: Train Loss 4.096e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.096058, 0.055561, 0.140495
# [0.0001]
# 401: Train Loss 3.761e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.091985, 0.053265, 0.135446
# [0.0001]
# 451: Train Loss 3.374e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.086744, 0.050447, 0.128904
# [0.0001]
# 501: Train Loss 2.997e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.081611, 0.047523, 0.120937
# [0.0001]
# 551: Train Loss 2.662e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.076119, 0.044779, 0.114519
# [0.0001]
# 601: Train Loss 2.451e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.073427, 0.043284, 0.111190
# [0.0001]
# 651: Train Loss 2.257e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.069352, 0.040987, 0.104181
# [0.0001]
# 701: Train Loss 2.089e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.070313, 0.040587, 0.106127
# [0.0001]
# 751: Train Loss 1.929e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.063825, 0.038307, 0.097184
# [0.0001]
# 801: Train Loss 1.847e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.063097, 0.037677, 0.099082
# [0.0001]
# 851: Train Loss 1.771e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.059069, 0.036017, 0.098312
# [0.0001]
# 901: Train Loss 1.660e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.058183, 0.035296, 0.092534
# [0.0001]
# 951: Train Loss 1.575e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.057479, 0.035007, 0.092993
# Finished training TI model FFNet at Tue Oct  1 21:21:49 2024...
# Model saved at savedmodels/timeinput/tscaleFFNet-01-October-2024-21.21.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [40273393.0, (500, 51, 512)]
# Loading model from savedmodels/timeinput\tscaleFFNet-01-October-2024-21.21.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [45651769.0, (500, 51, 512)]
# Load failed. Could not match with any files
# ['savedmodels/timeinput\\tshiftFFNet-01-October-2024-20.29.pickle']
# Tensorboard writer location is ./tensorboard/01-October-2024/tshiftFFNet/21.21.51/
# Number of NN trainable parameters 731712
# Starting training TI model FFNet at Tue Oct  1 21:21:51 2024...
# train torch.Size([400, 51, 512]) test (100, 51, 512)
# [0.001]
# 1: Train Loss 1.683e-02, LR 1.000e-03, Relative TI Error (1, 2, inf): 1.798584, 0.932727, 0.946833
# [0.001]
# 51: Train Loss 6.275e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.376901, 0.179469, 0.316002
# [0.001]
# 101: Train Loss 6.316e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.356571, 0.170079, 0.244276
# [0.001]
# 151: Train Loss 2.289e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.248910, 0.118805, 0.189616
# [0.001]
# 201: Train Loss 2.404e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.254196, 0.125619, 0.193887
# [0.0001]
# 251: Train Loss 8.120e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.133820, 0.067108, 0.145612
# [0.0001]
# 301: Train Loss 7.855e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.131432, 0.065967, 0.143541
# [0.0001]
# 351: Train Loss 7.552e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.128601, 0.064675, 0.141457
# [0.0001]
# 401: Train Loss 7.205e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.125286, 0.063175, 0.139136
# [0.0001]
# 451: Train Loss 6.794e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.121268, 0.061338, 0.135585
# [0.0001]
# 501: Train Loss 6.361e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.117104, 0.059359, 0.132655
# [0.0001]
# 551: Train Loss 6.004e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.113797, 0.057583, 0.129226
# [0.0001]
# 601: Train Loss 5.611e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.110511, 0.056010, 0.125775
# [0.0001]
# 651: Train Loss 5.620e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.115572, 0.057692, 0.123623
# [0.0001]
# 701: Train Loss 4.902e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.102202, 0.052262, 0.119023
# [0.0001]
# 751: Train Loss 4.683e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.100397, 0.051147, 0.116624
# [0.0001]
# 801: Train Loss 4.487e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.098774, 0.050022, 0.114087
# [0.0001]
# 851: Train Loss 4.512e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.098594, 0.050175, 0.113191
# [0.0001]
# 901: Train Loss 4.032e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.092874, 0.047485, 0.110242
# [0.0001]
# 951: Train Loss 4.095e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.094454, 0.048035, 0.109462
# Finished training TI model FFNet at Tue Oct  1 21:23:16 2024...
# Model saved at savedmodels/timeinput/tshiftFFNet-01-October-2024-21.23.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [45651769.0, (500, 51, 512)]
# Loading model from savedmodels/timeinput\tshiftFFNet-01-October-2024-21.23.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [81879307.0, (500, 51, 512)]
# Load failed. Could not match with any files
# ['savedmodels/timeinput\\kscaleFFNet-01-October-2024-20.31.pickle']
# Tensorboard writer location is ./tensorboard/01-October-2024/kscaleFFNet/21.23.26/
# Number of NN trainable parameters 731712
# Starting training TI model FFNet at Tue Oct  1 21:23:26 2024...
# train torch.Size([400, 51, 512]) test (100, 51, 512)
# [0.001]
# 1: Train Loss 1.530e-02, LR 1.000e-03, Relative TI Error (1, 2, inf): 1.129712, 0.761214, 0.911614
# [0.001]
# 51: Train Loss 5.112e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.162895, 0.112630, 0.251154
# [0.001]
# 101: Train Loss 1.812e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.096252, 0.068448, 0.167472
# [0.001]
# 151: Train Loss 1.406e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.102752, 0.066546, 0.153725
# [0.001]
# 201: Train Loss 2.856e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.124520, 0.085977, 0.176973
# [0.001]
# 251: Train Loss 1.964e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.118831, 0.077193, 0.151198
# [0.0001]
# 301: Train Loss 3.061e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.035765, 0.026245, 0.079446
# [0.0001]
# 351: Train Loss 2.911e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.034992, 0.025626, 0.076837
# [0.0001]
# 401: Train Loss 2.781e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.034253, 0.025049, 0.074625
# [0.0001]
# 451: Train Loss 2.568e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.033459, 0.024424, 0.072717
# [0.0001]
# 501: Train Loss 2.390e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.032302, 0.023455, 0.070140
# [0.0001]
# 551: Train Loss 2.147e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.031320, 0.022659, 0.068527
# [0.0001]
# 601: Train Loss 1.993e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.031231, 0.022520, 0.069117
# [0.0001]
# 651: Train Loss 1.757e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.030073, 0.021470, 0.066554
# [0.0001]
# 701: Train Loss 1.567e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.029209, 0.020635, 0.064288
# [0.0001]
# 751: Train Loss 1.419e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.028213, 0.019814, 0.061828
# [0.0001]
# 801: Train Loss 1.376e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.028535, 0.019988, 0.060807
# [0.0001]
# 851: Train Loss 1.169e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.025708, 0.018108, 0.057557
# [0.0001]
# 901: Train Loss 1.109e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.026577, 0.018446, 0.057094
# [0.0001]
# 951: Train Loss 9.988e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.024319, 0.016926, 0.053792
# Finished training TI model FFNet at Tue Oct  1 21:24:51 2024...
# Model saved at savedmodels/timeinput/kscaleFFNet-01-October-2024-21.24.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [81879307.0, (500, 51, 512)]
# Loading model from savedmodels/timeinput\kscaleFFNet-01-October-2024-21.24.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [144840538.0, (500, 51, 512)]
# Load failed. Could not match with any files
# ['savedmodels/timeinput\\kshiftFFNet-01-October-2024-20.33.pickle']
# Tensorboard writer location is ./tensorboard/01-October-2024/kshiftFFNet/21.25.11/
# Number of NN trainable parameters 731712
# Starting training TI model FFNet at Tue Oct  1 21:25:11 2024...
# train torch.Size([400, 51, 512]) test (100, 51, 512)
# [0.001]
# 1: Train Loss 3.956e-02, LR 1.000e-03, Relative TI Error (1, 2, inf): 1.069602, 0.717739, 0.889643
# [0.001]
# 51: Train Loss 1.618e-04, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.074709, 0.047009, 0.140674
# [0.001]
# 101: Train Loss 3.378e-05, LR 1.000e-03, Relative TI Error (1, 2, inf): 0.034968, 0.021925, 0.074586
# [0.0001]
# 151: Train Loss 1.656e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.023577, 0.014832, 0.057036
# [0.0001]
# 201: Train Loss 1.511e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.022629, 0.014178, 0.054184
# [0.0001]
# 251: Train Loss 1.359e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.021588, 0.013458, 0.050624
# [0.0001]
# 301: Train Loss 1.198e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.020352, 0.012625, 0.046460
# [0.0001]
# 351: Train Loss 1.036e-05, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.019020, 0.011734, 0.041883
# [0.0001]
# 401: Train Loss 8.793e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.017572, 0.010773, 0.037242
# [0.0001]
# 451: Train Loss 7.664e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.016374, 0.009987, 0.033505
# [0.0001]
# 501: Train Loss 6.923e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.015453, 0.009406, 0.031475
# [0.0001]
# 551: Train Loss 5.936e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.014744, 0.008981, 0.029052
# [0.0001]
# 601: Train Loss 4.784e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.012948, 0.007851, 0.026385
# [0.0001]
# 651: Train Loss 5.187e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.014042, 0.008559, 0.025037
# [0.0001]
# 701: Train Loss 4.277e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.012269, 0.007447, 0.024328
# [0.0001]
# 751: Train Loss 6.235e-06, LR 1.000e-04, Relative TI Error (1, 2, inf): 0.015426, 0.009939, 0.025396
# [1e-05]
# 801: Train Loss 3.008e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.010295, 0.006269, 0.022152
# [1e-05]
# 851: Train Loss 2.975e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.010243, 0.006235, 0.022046
# [1e-05]
# 901: Train Loss 2.935e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.010168, 0.006189, 0.021867
# [1e-05]
# 951: Train Loss 2.879e-06, LR 1.000e-05, Relative TI Error (1, 2, inf): 0.010091, 0.006138, 0.021589
# Finished training TI model FFNet at Tue Oct  1 21:26:34 2024...
# Model saved at savedmodels/timeinput/kshiftFFNet-01-October-2024-21.26.pickle
# Searching for [<class 'models.FFNet'>, ([513, 400, 400, 400, 512],)] [144840538.0, (500, 51, 512)]
# Loading model from savedmodels/timeinput\kshiftFFNet-01-October-2024-21.26.pickle
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
